# %% [markdown]
# # Chapter 1 - Getting Started
# Based on "Forecasting: Principles and Practice, the Pythonic Way".
#
# Let us start with an overview of forecasting and the data we shall be using throught these notes.
# ## **1. Basic Steps**
# a) Problem Definition
#
# b) Gather Data
#
# c) Preliminary Exploratory Analysis: Always start by graphing the data. Are there consistent patterns? Is there a significant trend? Is seasonality important? Is there evidence of the presence of business cycles? Are there any outliers in the data that need to be explained by those with expert knowledge? How strong are the relationships among the variables available for analysis?
#
# d) Picking a Model
#
# e) Evaluate the forecast

# %% [markdown]
# # Chapter 2 -  Time series graphics
# Next, let us explore our dataset and investigate the time series.
#
# ## **1. Our Dataset**
#
# The data we are using is from the Mosqlimate research group, and consists in the number of dengue reported cases
# at the different municipalities of Brazil from 2010 to 2024.
#
# Our target column is `casos`. Each municipality has a unique `geocode`. Moreover, the data is divided into epiweeks (epidemiological weeks).

# %%
import polars as pl 
import numpy as np
import os
from dotenv import load_dotenv
from matplotlib import pyplot as plt
from lets_plot import *
LetsPlot.setup_html()

# Load environment variables from .env file
load_dotenv()
# Retrieve the dataset path from the environment variable
DATASET = os.getenv('DATASET')
df = pl.read_parquet(DATASET)
df.head()
# Out:
#             <div id="K9rpI0"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("K9rpI0").appendChild(div);
#                     };
#                     var e = document.getElementById("K9rpI0");
#                     e.appendChild(script);
#                 })()
#             </script>
# shape: (5, 45)
# ┌─────────────┬─────────┬──────┬───────┬───┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ date        ┆ epiweek ┆ week ┆ month ┆ … ┆ cope_foreca ┆ cope_foreca ┆ cope_foreca ┆ cope_foreca │
# │ ---         ┆ ---     ┆ ---  ┆ ---   ┆   ┆ st_precip_t ┆ st_precip_t ┆ st_precip_t ┆ st_precip_t │
# │ datetime[ms ┆ i64     ┆ i64  ┆ i8    ┆   ┆ ot_3        ┆ ot_4        ┆ ot_5        ┆ ot_6        │
# │ ]           ┆         ┆      ┆       ┆   ┆ ---         ┆ ---         ┆ ---         ┆ ---         │
# │             ┆         ┆      ┆       ┆   ┆ f64         ┆ f64         ┆ f64         ┆ f64         │
# ╞═════════════╪═════════╪══════╪═══════╪═══╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ 2017-10-15  ┆ 201742  ┆ 42   ┆ 10    ┆ … ┆ 0.0001143   ┆ 0.0001184   ┆ 0.0001067   ┆ 0.0000713   │
# │ 00:00:00    ┆         ┆      ┆       ┆   ┆             ┆             ┆             ┆             │
# │ 2022-03-27  ┆ 202213  ┆ 13   ┆ 3     ┆ … ┆ 0.0000159   ┆ 0.0000107   ┆ 0.0000086   ┆ 0.0000133   │
# │ 00:00:00    ┆         ┆      ┆       ┆   ┆             ┆             ┆             ┆             │
# │ 2018-01-07  ┆ 201802  ┆ 2    ┆ 1     ┆ … ┆ 0.0000557   ┆ 0.0000436   ┆ 0.0000431   ┆ 0.0000403   │
# │ 00:00:00    ┆         ┆      ┆       ┆   ┆             ┆             ┆             ┆             │
# │ 2020-02-23  ┆ 202009  ┆ 9    ┆ 2     ┆ … ┆ 0.0000243   ┆ 0.0000222   ┆ 0.0000215   ┆ 0.0000122   │
# │ 00:00:00    ┆         ┆      ┆       ┆   ┆             ┆             ┆             ┆             │
# │ 2019-08-25  ┆ 201935  ┆ 35   ┆ 8     ┆ … ┆ 0.0000005   ┆ 0.0000008   ┆ 0.0000057   ┆ 0.0000277   │
# │ 00:00:00    ┆         ┆      ┆       ┆   ┆             ┆             ┆             ┆             │
# └─────────────┴─────────┴──────┴───────┴───┴─────────────┴─────────────┴─────────────┴─────────────┘

# %%
df['year'].unique()
# Out:
# shape: (16,)
# Series: 'year' [i64]
# [
# 	2010
# 	2011
# 	2012
# 	2013
# 	2014
# 	…
# 	2021
# 	2022
# 	2023
# 	2024
# 	2025
# ]

# %% [markdown]
# Let's visualize our target.

# %%
sns.displot(data=df, x='casos', fill=True, color='blue', alpha=0.5)

# %% [markdown]
# Our variable is clearly heavy tailed. In order to better understand it, we must scale it.
# Moreover, we will also create a new variable that is the number of cases per 100,000 inhabitants, which we will call `dir` (dengue incidence rate).

# %%
df = df.with_columns(
    np.log1p(pl.col('casos')).alias('log_casos'),
    ((pl.col('casos')/pl.col('population')) *100000).alias('dir'),
    np.log1p(((pl.col('casos')/pl.col('population')) *100000)).alias('log_dir'),
)

# %%
sns.displot(data=df, x='log_casos', fill=True, color='blue', alpha=0.5)

# %% [markdown]
# The data has a large number of `0` cases. It might be that most of the weeks have no cases, and only a few weeks have a large number of cases.
# Thus, let us see the distribution of the number of cases per municipality summed over a whole year.
#
# Note, our dataset has **5567** municipalities.

# %%
len(gdf['geocode'].unique())
# Out:
# 5567

# %%
gdf = df.group_by(['geocode','year']).agg(
    pl.col('casos').sum().alias('casos'),
).sort('year')
gdf = gdf.with_columns(
    np.log1p(pl.col('casos')).alias('log_casos')
)

sns.displot(data=gdf, x='log_casos',fill=True, color='blue', alpha=0.5, col='year')

# %% [markdown]
# Note that we still have many cases with zeros, i.e., many municipalities report 0 across the whole year, with the exception of 2024,
# where the number of municipalities with 0 cases shrunk under 500.

# %%
# sns.displot(data=gdf, x='log_casos',fill=True, color='blue', alpha=0.5, col='year')
gdf
# Out:
# shape: (50_049, 4)
# ┌─────────┬──────┬───────┬───────────┐
# │ geocode ┆ year ┆ casos ┆ log_casos │
# │ ---     ┆ ---  ┆ ---   ┆ ---       │
# │ i64     ┆ i64  ┆ i64   ┆ f64       │
# ╞═════════╪══════╪═══════╪═══════════╡
# │ 1503093 ┆ 2017 ┆ 150   ┆ 5.01728   │
# │ 2600906 ┆ 2017 ┆ 0     ┆ 0.0       │
# │ 1718550 ┆ 2017 ┆ 3     ┆ 1.386294  │
# │ 2304400 ┆ 2017 ┆ 23431 ┆ 10.061858 │
# │ 2800407 ┆ 2017 ┆ 0     ┆ 0.0       │
# │ …       ┆ …    ┆ …     ┆ …         │
# │ 5219100 ┆ 2025 ┆ 40    ┆ 3.713572  │
# │ 4214706 ┆ 2025 ┆ 5     ┆ 1.791759  │
# │ 3100203 ┆ 2025 ┆ 19    ┆ 2.995732  │
# │ 2306900 ┆ 2025 ┆ 49    ┆ 3.912023  │
# │ 2505600 ┆ 2025 ┆ 0     ┆ 0.0       │
# └─────────┴──────┴───────┴───────────┘

# %%
# np.all(np.array(df['population'] > 0))
# Check if all values in the 'population' column are greater than 0
# df.select((pl.col('population') > 0).all()).item()
# print("All population values > 0:", all_population_positive)

# %%
# fortaleza = df.filter(pl.col('municipality') == 'Fortaleza (CE)')
fortaleza = df.filter(pl.col('municipality').is_in(['Fortaleza (CE)']))

# %%
gdf = df.group_by(['geocode','year']).agg(
    pl.col('casos').sum().alias('casos'),
    pl.col('population').mean().alias('population'),
).sort('year')

gdf = gdf.filter(pl.col('casos')>3)
gdf = gdf.with_columns(
    ((pl.col('casos')/pl.col('population')) *100000).alias('dir'),
    np.log1p(pl.col('casos')).alias('log_casos'),
    np.log1p(((pl.col('casos')/pl.col('population')) *100000)).alias('log_dir'),
)

# %%
# (
#     ggplot(data=gdf)
#     + geom_point(aes(x='population', y='log_dir'),alpha=0.1)
#     + scale_x_log10()
#     # + scale_y_log10()
# )

# %%
# import seaborn as sns
# sns.scatterplot(data=gdf, x='population', y='log_dir',alpha=0.1)
# plt.xscale('log')
# plt.yscale('log')

# %%
# fortaleza['casos']

# %%
(
    ggplot(data=fortaleza.filter(pl.col('year')>2018))
    # + geom_line(aes(x='date',y='casos'))
    # + geom_line(aes(x='date',y='dir'))
    # + geom_line(aes(x='date',y='log_casos'))
    + geom_line(aes(x='week',y='log_dir',color=as_discrete('year',order=1)))
    + scale_color_brewer(type='seq',palette='Blues',direction=1)
)
# Out:
#    <div id="8TuSl0"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("8TuSl0");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "week":[43.0,47.0,15.0,42.0,26.0,47.0,5.0,43.0,12.0,24.0,23.0,2.0,6.0,37.0,45.0,36.0,29.0,15.0,43.0,9.0,10.0,18.0,15.0,18.0,29.0,13.0,46.0,43.0,4.0,52.0,44.0,2.0,9.0,10.0,10.0,14.0,50.0,8.0,16.0,2.0,32.0,3.0,38.0,7.0,35.0,33.0,24.0,35.0,17.0,9.0,25.0,9.0,11.0,30.0,50.0,33.0,34.0,8.0,20.0,37.0,12.0,36.0,11.0,14.0,2.0,51.0,35.0,50.0,34.0,3.0,27.0,6.0,33.0,11.0,40.0,23.0,51.0,18.0,46.0,50.0,25.0,39.0,28.0,41.0,6.0,18.0,19.0,8.0,40.0,8.0,10.0,3.0,23.0,20.0,21.0,29.0,32.0,6.0,9.0,25.0,11.0,48.0,26.0,48.0,48.0,30.0,31.0,3.0,44.0,18.0,22.0,16.0,15.0,42.0,52.0,49.0,16.0,22.0,45.0,35.0,16.0,17.0,47.0,32.0,2.0,31.0,23.0,13.0,41.0,5.0,31.0,39.0,12.0,41.0,44.0,47.0,19.0,45.0,20.0,53.0,36.0,38.0,28.0,51.0,48.0,51.0,41.0,33.0,19.0,35.0,26.0,21.0,40.0,20.0,14.0,14.0,43.0,29.0,10.0,30.0,34.0,52.0,21.0,34.0,31.0,48.0,52.0,15.0,19.0,41.0,36.0,5.0,4.0,44.0,36.0,22.0,40.0,27.0,49.0,42.0,1.0,16.0,28.0,7.0,37.0,26.0,36.0,40.0,25.0,17.0,32.0,8.0,13.0,49.0,43.0,12.0,6.0,8.0,46.0,49.0,38.0,7.0,24.0,3.0,28.0,42.0,46.0,32.0,9.0,27.0,30.0,42.0,12.0,44.0,5.0,4.0,2.0,39.0,49.0,38.0,18.0,48.0,22.0,49.0,41.0,5.0,38.0,39.0,37.0,27.0,50.0,37.0,4.0,46.0,14.0,12.0,13.0,27.0,47.0,13.0,29.0,45.0,7.0,4.0,22.0,26.0,4.0,45.0,40.0,50.0,42.0,6.0,1.0,1.0,17.0,11.0,28.0,15.0,28.0,26.0,21.0,20.0,1.0,1.0,1.0,33.0,37.0,7.0,45.0,11.0,17.0,35.0,14.0,24.0,24.0,30.0,25.0,19.0,17.0,19.0,7.0,5.0,23.0,52.0,39.0,39.0,10.0,52.0,38.0,44.0,16.0,20.0,24.0,51.0,22.0,23.0,33.0,47.0,32.0,51.0,31.0,30.0,13.0,46.0,21.0,34.0,34.0,25.0,31.0,29.0,27.0,21.0,3.0],
